# %%
from dask.distributed import Client, progress
# Scale up: connect to your own cluster with bmore resources
# see http://dask.pydata.org/en/latest/setup.html
client = Client(processes=False, threads_per_worker=4,
                n_workers=1, memory_limit='2GB')
client
# Out:
# <Client: 'inproc://192.168.1.16/95474/1' processes=1 threads=4, memory=2.00 GB>

# %%
from datasetinsights.data.datasets.synthetic import SynDetection2D
import datasetinsights.constants as const

data_root = "/Users/youcyuan/data"
run_execution_id = "wjZR6Zj"
definition_id = "c31620e3-55ff-4af6-ae86-884aa0daa9b2"

data = SynDetection2D(
    data_root=data_root,
    run_execution_id=run_execution_id,
    def_id=definition_id,
)

#     for i in tqdm(range(len(data))):
#         data[i]
# Out:
# Filename: /Users/youcyuan/Projects/dataset-insights/datasetinsights/data/simulation/captures.py
#
# Line #    Mem usage    Increment   Line Contents
# ...
#     52    305.6 MiB    305.6 MiB       @profile
#     53                                 def _load_captures(self, data_root, version):
#     54                                     """Load captures except annotations.
#     55                                     :ref:`captures`
#     56
#     57                                     Args:
#     58                                         data_root (str): the root directory of the dataset
#     59                                         version (str): desired schema version
#     60
#     61                                     Returns:
#     62                                         A dask bag of captures except annotations
#     63                                     """
#     64    305.6 MiB      0.0 MiB           capture_files = glob(data_root, self.FILE_PATTERN)
# ...
